# %%
# importing required libraries
import matplotlib.pyplot as plt
import matplotlib.image as img
  
# reading the image
testImage = img.imread('steph-curry_Slice_RLV_2022-1600x1066.jpg')
  
# displaying the image
plt.imshow(testImage)
